# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file = "lastone.csv"
data = pd.read_csv(file)
data
# Out:
#      Unnamed: 0  Census  Number of Crimes  Total Population  \
# 0             0     201                23              24.0
# 1             1     202               603            3595.0
# 2             2     501               105            3593.0
# 3             3     502                65            3296.0
# 4             4     701                43            5643.0
# ..          ...     ...               ...               ...
# 122         122    9903                98            1952.0
# 123         123    9904               118            2948.0
# 124         124    9905               144            2852.0
# 125         125    9906                86            1623.0
# 126         126    9907               108            2773.0
#
#      Percentage of Population in Poverty  Percentage of Children in Poverty  \
# 0                                  100.0                          25.055524
# 1                                   16.2                           0.000000
# 2                                    7.1                          10.900000
# 3                                    2.8                           0.000000
# 4                                   11.7                           8.000000
# ..                                   ...                                ...
# 122                                 19.3                          34.100000
# 123                                 35.3                          48.100000
# 124                                 28.4                          44.400000
# 125                                 22.9                          27.700000
# 126                                 28.8                          47.100000
#
#       Latitude  Longitude
# 0    38.911904 -77.074202
# 1    38.906516 -77.065324
# 2    38.924631 -77.052344
# 3    38.928411 -77.057113
# 4    38.930409 -77.075336
# ..         ...        ...
# 122  38.888687 -76.920801
# 123  38.884916 -76.930460
# 124  38.884172 -76.924967
# 125  38.888275 -76.935810
# 126  38.882561 -76.937396
#
# [127 rows x 8 columns]

# %%
gbdata1 = data.groupby(['Census','Number of Crimes']).count()
gbdata1
# Out:
#                          Unnamed: 0  Total Population  \
# Census Number of Crimes
# 201    23                         1                 1
# 202    603                        1                 1
# 501    105                        1                 1
# 502    65                         1                 1
# 701    43                         1                 1
# ...                             ...               ...
# 9903   98                         1                 1
# 9904   118                        1                 1
# 9905   144                        1                 1
# 9906   86                         1                 1
# 9907   108                        1                 1
#
#                          Percentage of Population in Poverty  \
# Census Number of Crimes
# 201    23                                                  1
# 202    603                                                 1
# 501    105                                                 1
# 502    65                                                  1
# 701    43                                                  1
# ...                                                      ...
# 9903   98                                                  1
# 9904   118                                                 1
# 9905   144                                                 1
# 9906   86                                                  1
# 9907   108                                                 1
#
#                          Percentage of Children in Poverty  Latitude  \
# Census Number of Crimes
# 201    23                                                1         1
# 202    603                                               1         1
# 501    105                                               1         1
# 502    65                                                1         1
# 701    43                                                1         1
# ...                                                    ...       ...
# 9903   98                                                1         1
# 9904   118                                               1         1
# 9905   144                                               1         1
# 9906   86                                                1         1
# 9907   108                                               1         1
#
#                          Longitude
# Census Number of Crimes
# 201    23                        1
# 202    603                       1
# 501    105                       1
# 502    65                        1
# 701    43                        1
# ...                            ...
# 9903   98                        1
# 9904   118                       1
# 9905   144                       1
# 9906   86                        1
# 9907   108                       1
#
# [127 rows x 6 columns]

# %%
gbdata = gbdata.reset_index()
gbdata
# Out:
#      Census  Number of Crimes  Unnamed: 0  Total Population  \
# 0       201                23           1                 1
# 1       202               603           1                 1
# 2       501               105           1                 1
# 3       502                65           1                 1
# 4       701                43           1                 1
# ..      ...               ...         ...               ...
# 122    9903                98           1                 1
# 123    9904               118           1                 1
# 124    9905               144           1                 1
# 125    9906                86           1                 1
# 126    9907               108           1                 1
#
#      Percentage of Population in Poverty  Percentage of Children in Poverty  \
# 0                                      1                                  1
# 1                                      1                                  1
# 2                                      1                                  1
# 3                                      1                                  1
# 4                                      1                                  1
# ..                                   ...                                ...
# 122                                    1                                  1
# 123                                    1                                  1
# 124                                    1                                  1
# 125                                    1                                  1
# 126                                    1                                  1
#
#      Latitude  Longitude
# 0           1          1
# 1           1          1
# 2           1          1
# 3           1          1
# 4           1          1
# ..        ...        ...
# 122         1          1
# 123         1          1
# 124         1          1
# 125         1          1
# 126         1          1
#
# [127 rows x 8 columns]

# %%
topten = data.sort_values('Percentage of Population in Poverty', ascending= False)
topten
# Out:
#     Unnamed: 0  Census  Number of Crimes  Total Population  \
# 0            0     201                23              24.0
# 57          57    7401               143            2262.0
# 62          62    7408                95            2994.0
# 92          92    8803               391            1767.0
# 60          60    7406               173            3246.0
# ..         ...     ...               ...               ...
# 85          85    8301               139            2350.0
# 39          39    4201               119            3724.0
# 3            3     502                65            3296.0
# 9            9     902                38            2584.0
# 51          51    6202               186              72.0
#
#     Percentage of Population in Poverty  Percentage of Children in Poverty  \
# 0                                 100.0                          25.055524
# 57                                 64.6                          69.000000
# 62                                 52.6                          77.100000
# 92                                 48.6                          62.600000
# 60                                 48.5                          55.500000
# ..                                  ...                                ...
# 85                                  3.4                           0.000000
# 39                                  3.1                           0.000000
# 3                                   2.8                           0.000000
# 9                                   2.2                           0.700000
# 51                                  0.0                          25.055524
#
#      Latitude  Longitude
# 0   38.911904 -77.074202
# 57  38.860443 -76.995674
# 62  38.853319 -76.970368
# 92  38.912086 -76.989589
# 60  38.855362 -76.989345
# ..        ...        ...
# 85  38.898280 -77.000785
# 39  38.916383 -77.038252
# 3   38.928411 -77.057113
# 9   38.927189 -77.104387
# 51  38.895126 -77.019261
#
# [127 rows x 8 columns]

# %%
bottomten = data.sort_values('Percentage of Population in Poverty', ascending= True)
bottomten
# Out:
#     Unnamed: 0  Census  Number of Crimes  Total Population  \
# 51          51    6202               186              72.0
# 9            9     902                38            2584.0
# 3            3     502                65            3296.0
# 39          39    4201               119            3724.0
# 85          85    8301               139            2350.0
# ..         ...     ...               ...               ...
# 60          60    7406               173            3246.0
# 92          92    8803               391            1767.0
# 62          62    7408                95            2994.0
# 57          57    7401               143            2262.0
# 0            0     201                23              24.0
#
#     Percentage of Population in Poverty  Percentage of Children in Poverty  \
# 51                                  0.0                          25.055524
# 9                                   2.2                           0.700000
# 3                                   2.8                           0.000000
# 39                                  3.1                           0.000000
# 85                                  3.4                           0.000000
# ..                                  ...                                ...
# 60                                 48.5                          55.500000
# 92                                 48.6                          62.600000
# 62                                 52.6                          77.100000
# 57                                 64.6                          69.000000
# 0                                 100.0                          25.055524
#
#      Latitude  Longitude
# 51  38.895126 -77.019261
# 9   38.927189 -77.104387
# 3   38.928411 -77.057113
# 39  38.916383 -77.038252
# 85  38.898280 -77.000785
# ..        ...        ...
# 60  38.855362 -76.989345
# 92  38.912086 -76.989589
# 62  38.853319 -76.970368
# 57  38.860443 -76.995674
# 0   38.911904 -77.074202
#
# [127 rows x 8 columns]

# %%
data201 = gbdata[gbdata['Census']==201]
data201
# Out:
#    Census  Number of Crimes  Unnamed: 0  Total Population  \
# 0     201                23           1                 1
#
#    Percentage of Population in Poverty  Percentage of Children in Poverty  \
# 0                                    1                                  1
#
#    Latitude  Longitude
# 0         1          1

# %%
#Barchart with Number of Crimes for the Top 10 Areas of Poverty
x_axis = np.arange(len(topten.head(20)))
bar =topten.head(20)["Number of Crimes"]
tick_locations = [value for value in x_axis]
bar.plot(kind="bar", align = 'center')
plt.xlabel("Census Tract")
plt.xticks(tick_locations, topten['Census'], rotation=45,)
plt.ylabel("Number of Crimes")
plt.title("Top 20 Areas of Poverty vs amount of Crimes that Occur")
plt.show()

# %%
x_axis = np.arange(len(bottomten.head(20)))
bar =bottomten.head(20)["Number of Crimes"]
tick_locations = [value for value in x_axis]
bar.plot(kind="bar", align = 'center')
plt.xlabel("Census Tract")
plt.xticks(tick_locations, bottomten['Census'], rotation=45,)
plt.ylabel("Number of Crimes")
plt.title("Bottom 20 Areas of Poverty vs amount of Crimes that Occur")
plt.show()

# %%
#Make a scatterplot of Total Poverty vs Child Poverty
data.plot.scatter(x = ('Total Population'), y = ('Number of Crimes'))

plt.ylabel("Number of Crimes")
plt.xlabel("Total Population ")
plt.title("Total Population vs Number of Crimes Occured")
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)
plt.show()

# %%
data.plot.scatter(x = ('Percentage of Children in Poverty'), y = ('Number of Crimes'))

plt.ylabel("Number of Crimes")
plt.xlabel("Child Poverty")
plt.title("Child Poverty vs Number of Crimes Occured")
plt.show()
