# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file = "../Resources/ACS_2017_Poverty_Status_Variables_Tract.csv"
poverty_csv = pd.read_csv(file)
poverty_csv.head()
# Out:
#    OBJECTID        GEOID    ALAND  AWATER               NAME  \
# 0         1  11001000100  1907610  512798     Census Tract 1
# 1         2  11001000201   503312       0  Census Tract 2.01
# 2         3  11001000202   776630  428562  Census Tract 2.02
# 3         4  11001000300  1010813    2334     Census Tract 3
# 4         5  11001000400  1542760      69     Census Tract 4
#
#                   State                County  B17020_001E  B17020_001M  \
# 0  District of Columbia  District of Columbia         5151          348
# 1  District of Columbia  District of Columbia           24           56
# 2  District of Columbia  District of Columbia         3595          557
# 3  District of Columbia  District of Columbia         6374          569
# 4  District of Columbia  District of Columbia         1485          130
#
#    B17020_002E  ...  B17020_calc_numChildPovE  B17020_calc_numChildPovM  \
# 0          248  ...                        27                        38
# 1           24  ...                         0                        21
# 2          582  ...                         0                        21
# 3         1184  ...                        29                        37
# 4          169  ...                        28                        27
#
#    B17020_calc_pctChildPovE  B17020_calc_pctChildPovM   Shape__Area  \
# 0                       3.4                  4.610801  3.157970e+06
# 1                       NaN                       NaN  8.324142e+05
# 2                       0.0                  5.898876  1.284189e+06
# 3                       3.4                  4.296579  1.676009e+06
# 4                      10.0                  9.329003  2.552696e+06
#
#    Shape__Length  B17020_calc_numTotChildE  B17020_calc_numTotChildM  \
# 0   16275.593084                       802                       257
# 1    4265.956241                         0                        29
# 2   13196.755434                       356                       141
# 3    5244.313860                       847                       196
# 4    7468.467690                       281                        65
#
#    Shape__Area_2  Shape__Length_2
# 0   3.157970e+06     16275.593084
# 1   8.324142e+05      4265.956241
# 2   1.284189e+06     13196.755434
# 3   1.676009e+06      5244.313860
# 4   2.552696e+06      7468.467690
#
# [5 rows x 53 columns]

# %%
poverty_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   OBJECTID                  179 non-null    int64
#  1   GEOID                     179 non-null    int64
#  2   ALAND                     179 non-null    int64
#  3   AWATER                    179 non-null    int64
#  4   NAME                      179 non-null    object
#  5   State                     179 non-null    object
#  6   County                    179 non-null    object
#  7   B17020_001E               179 non-null    int64
#  8   B17020_001M               179 non-null    int64
#  9   B17020_002E               179 non-null    int64
#  10  B17020_002M               179 non-null    int64
#  11  B17020_003E               179 non-null    int64
#  12  B17020_003M               179 non-null    int64
#  13  B17020_004E               179 non-null    int64
#  14  B17020_004M               179 non-null    int64
#  15  B17020_005E               179 non-null    int64
#  16  B17020_005M               179 non-null    int64
#  17  B17020_006E               179 non-null    int64
#  18  B17020_006M               179 non-null    int64
#  19  B17020_007E               179 non-null    int64
#  20  B17020_007M               179 non-null    int64
#  21  B17020_008E               179 non-null    int64
#  22  B17020_008M               179 non-null    int64
#  23  B17020_009E               179 non-null    int64
#  24  B17020_009M               179 non-null    int64
#  25  B17020_010E               179 non-null    int64
#  26  B17020_010M               179 non-null    int64
#  27  B17020_011E               179 non-null    int64
#  28  B17020_011M               179 non-null    int64
#  29  B17020_012E               179 non-null    int64
#  30  B17020_012M               179 non-null    int64
#  31  B17020_013E               179 non-null    int64
#  32  B17020_013M               179 non-null    int64
#  33  B17020_014E               179 non-null    int64
#  34  B17020_014M               179 non-null    int64
#  35  B17020_015E               179 non-null    int64
#  36  B17020_015M               179 non-null    int64
#  37  B17020_016E               179 non-null    int64
#  38  B17020_016M               179 non-null    int64
#  39  B17020_017E               179 non-null    int64
#  40  B17020_017M               179 non-null    int64
#  41  B17020_calc_pctPovE       179 non-null    float64
#  42  B17020_calc_pctPovM       179 non-null    float64
#  43  B17020_calc_numChildPovE  179 non-null    int64
#  44  B17020_calc_numChildPovM  179 non-null    int64
#  45  B17020_calc_pctChildPovE  176 non-null    float64
#  46  B17020_calc_pctChildPovM  176 non-null    float64
#  47  Shape__Area               179 non-null    float64
#  48  Shape__Length             179 non-null    float64
#  49  B17020_calc_numTotChildE  179 non-null    int64
#  50  B17020_calc_numTotChildM  179 non-null    int64
#  51  Shape__Area_2             179 non-null    float64
#  52  Shape__Length_2           179 non-null    float64
# dtypes: float64(8), int64(42), object(3)
# memory usage: 74.2+ KB

# %%
poverty_df = pd.DataFrame(poverty_csv, columns=['NAME','B17020_calc_pctPovE', 'B17020_calc_pctChildPovE'])
poverty_df
# Out:
#                   NAME  B17020_calc_pctPovE  B17020_calc_pctChildPovE
# 0       Census Tract 1                  4.8                       3.4
# 1    Census Tract 2.01                100.0                       NaN
# 2    Census Tract 2.02                 16.2                       0.0
# 3       Census Tract 3                 18.6                       3.4
# 4       Census Tract 4                 11.4                      10.0
# ..                 ...                  ...                       ...
# 174   Census Tract 107                 20.3                       0.0
# 175   Census Tract 108                 45.6                       NaN
# 176   Census Tract 109                 43.8                      46.4
# 177   Census Tract 110                  6.6                       0.0
# 178   Census Tract 111                 21.2                       7.5
#
# [179 rows x 3 columns]

# %%
poverty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   NAME                      179 non-null    object
#  1   B17020_calc_pctPovE       179 non-null    float64
#  2   B17020_calc_pctChildPovE  176 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.3+ KB

# %%
#Rename Columns
poverty_df.rename(columns = {'NAME': 'Census Tract','B17020_calc_pctPovE':'Percentage of Poverty', 'B17020_calc_pctChildPovE':'Percentage of Poverty in Children'}, inplace = True)
poverty_df
# Out:
#           Census Tract  Percentage of Poverty  \
# 0       Census Tract 1                    4.8
# 1    Census Tract 2.01                  100.0
# 2    Census Tract 2.02                   16.2
# 3       Census Tract 3                   18.6
# 4       Census Tract 4                   11.4
# ..                 ...                    ...
# 174   Census Tract 107                   20.3
# 175   Census Tract 108                   45.6
# 176   Census Tract 109                   43.8
# 177   Census Tract 110                    6.6
# 178   Census Tract 111                   21.2
#
#      Percentage of Poverty in Children
# 0                                  3.4
# 1                                  NaN
# 2                                  0.0
# 3                                  3.4
# 4                                 10.0
# ..                                 ...
# 174                                0.0
# 175                                NaN
# 176                               46.4
# 177                                0.0
# 178                                7.5
#
# [179 rows x 3 columns]

# %%
poverty_df1 = poverty_df.fillna(0)
poverty_df1
# Out:
#           Census Tract  Percentage of Poverty  \
# 0       Census Tract 1                    4.8
# 1    Census Tract 2.01                  100.0
# 2    Census Tract 2.02                   16.2
# 3       Census Tract 3                   18.6
# 4       Census Tract 4                   11.4
# ..                 ...                    ...
# 174   Census Tract 107                   20.3
# 175   Census Tract 108                   45.6
# 176   Census Tract 109                   43.8
# 177   Census Tract 110                    6.6
# 178   Census Tract 111                   21.2
#
#      Percentage of Poverty in Children
# 0                                  3.4
# 1                                  0.0
# 2                                  0.0
# 3                                  3.4
# 4                                 10.0
# ..                                 ...
# 174                                0.0
# 175                                0.0
# 176                               46.4
# 177                                0.0
# 178                                7.5
#
# [179 rows x 3 columns]

# %%
percentage_of_povt10 = poverty_df1.sort_values('Percentage of Poverty', ascending=False)
percentage_of_povt10.set_index("Census Tract")
percentage_of_povt10.head(10)
# Out:
#            Census Tract  Percentage of Poverty  \
# 1     Census Tract 2.01                  100.0
# 93   Census Tract 74.01                   64.6
# 98   Census Tract 74.08                   52.6
# 80      Census Tract 64                   49.4
# 130  Census Tract 88.03                   48.6
# 96   Census Tract 74.06                   48.5
# 155  Census Tract 98.02                   48.0
# 86   Census Tract 68.04                   47.0
# 175    Census Tract 108                   45.6
# 102  Census Tract 75.04                   45.0
#
#      Percentage of Poverty in Children
# 1                                  0.0
# 93                                69.0
# 98                                77.1
# 80                                75.8
# 130                               62.6
# 96                                55.5
# 155                               66.9
# 86                                 0.0
# 175                                0.0
# 102                               59.8

# %% [markdown]
# # Make a barchart with the Top 10 for Perecentage of Poverty

# %%
x_axis = np.arange(len(percentage_of_povt10.head(10)))
bar =percentage_of_povt10.head(10)["Percentage of Poverty"]
tick_locations = [value for value in x_axis]
bar.plot(kind="bar", align = 'center')
plt.xlabel("Census Tract")
plt.xticks(tick_locations, percentage_of_povt10['Census Tract'], rotation=45,)
plt.ylabel("Percentage of Poverty")
plt.title("Top 10 Areas of Highest Percentage of Poverty")
plt.show()

# %%
#Barchart with Top 10 Percentage of Child Poverty
percentage_of_child_pov10 = poverty_df1.sort_values('Percentage of Poverty in Children', ascending=False)
percentage_of_child_pov10.set_index("Census Tract")
percentage_of_child_pov10.head(10)
# Out:
#            Census Tract  Percentage of Poverty  \
# 98   Census Tract 74.08                   52.6
# 80      Census Tract 64                   49.4
# 93   Census Tract 74.01                   64.6
# 155  Census Tract 98.02                   48.0
# 154  Census Tract 98.01                   41.4
# 130  Census Tract 88.03                   48.6
# 102  Census Tract 75.04                   45.0
# 149  Census Tract 96.01                   41.0
# 64      Census Tract 46                   17.0
# 101  Census Tract 75.03                   41.5
#
#      Percentage of Poverty in Children
# 98                                77.1
# 80                                75.8
# 93                                69.0
# 155                               66.9
# 154                               65.8
# 130                               62.6
# 102                               59.8
# 149                               59.5
# 64                                59.3
# 101                               58.4

# %%
x_axis = np.arange(len(percentage_of_child_pov10.head(10)))
bar =percentage_of_child_pov10.head(10)["Percentage of Poverty in Children"]
tick_locations = [value for value in x_axis]
bar.plot(kind="bar", align = 'center')
plt.xlabel("Census Tract")
plt.xticks(tick_locations, percentage_of_child_pov10['Census Tract'], rotation=45,)
plt.ylabel("Percentage of Poverty in Children")
plt.title("Top 10 Areas of Children in Poverty")
plt.show()

# %%
#Barchart with Lowest 10 Poverty
bottom_ten = poverty_df1.sort_values('Percentage of Poverty', ascending=True)
bottom_ten.set_index("Census Tract")
bottom_ten.head(10)
# Out:
#            Census Tract  Percentage of Poverty  \
# 79   Census Tract 62.02                    0.0
# 121     Census Tract 81                    1.7
# 13    Census Tract 9.02                    2.2
# 6     Census Tract 5.02                    2.8
# 60   Census Tract 42.01                    3.1
# 123  Census Tract 83.01                    3.4
# 124  Census Tract 83.02                    3.5
# 57   Census Tract 40.01                    3.5
# 119  Census Tract 80.01                    3.6
# 82      Census Tract 66                    3.6
#
#      Percentage of Poverty in Children
# 79                                 0.0
# 121                                0.0
# 13                                 0.7
# 6                                  0.0
# 60                                 0.0
# 123                                0.0
# 124                                0.0
# 57                                 0.0
# 119                                0.0
# 82                                 0.0

# %%
x_axis = np.arange(len(bottom_ten.head(10)))
bar =bottom_ten.head(10)["Percentage of Poverty"]
tick_locations = [value for value in x_axis]
bar.plot(kind="bar", align = 'center')
plt.xlabel("Census Tract")
plt.xticks(tick_locations, bottom_ten['Census Tract'], rotation=45,)
plt.ylabel("Percentage of Poverty")
plt.title("Bottom 10 Areas of Poverty Percentage") 
plt.show()

# %%
#Barchart with Lowest 10 Children in Poverty
bottom_ten_children = poverty_df1.sort_values('Percentage of Poverty in Children', ascending=True)
bottom_ten_children.set_index("Census Tract")
bottom_ten_children.head(10)
# Out:
#            Census Tract  Percentage of Poverty  \
# 76      Census Tract 56                   22.6
# 161  Census Tract 99.01                    9.3
# 152  Census Tract 96.04                   12.1
# 148  Census Tract 95.09                    3.9
# 61   Census Tract 42.02                    5.0
# 60   Census Tract 42.01                    3.1
# 58   Census Tract 40.02                    3.7
# 144  Census Tract 95.04                    9.9
# 33   Census Tract 22.01                    7.1
# 143  Census Tract 95.03                    5.4
#
#      Percentage of Poverty in Children
# 76                                 0.0
# 161                                0.0
# 152                                0.0
# 148                                0.0
# 61                                 0.0
# 60                                 0.0
# 58                                 0.0
# 144                                0.0
# 33                                 0.0
# 143                                0.0

# %%
x_axis = np.arange(len(bottom_ten_children.head(10)))
bar =bottom_ten_children.head(10)["Percentage of Poverty in Children"]
tick_locations = [value for value in x_axis]
bar.plot(kind="bar", align = 'center')
plt.xlabel("Census Tract")
plt.xticks(tick_locations, bottom_ten_children['Census Tract'], rotation=45,)
plt.ylabel("Percentage of Poverty")
plt.title("Bottom 10 Areas of Children in Poverty Percentage") 
plt.show()

# %%
#Make a scatterplot of Total Poverty vs Child Poverty
poverty_df1.plot.scatter(y = "Percentage of Poverty", x = "Percentage of Poverty in Children")

plt.ylabel("Total Poverty")
plt.xlabel("Child Poverty ")
plt.title("Total Poverty vs Child Poverty")
plt.show()

# %%
#Make a boxplot of Top 10 Areas of Poverty by Name
#Convert the dataframe column to an array
a=percentage_of_povt10.head(10).iloc[:,1].values
b=percentage_of_povt10.head(10).iloc[:,2].values
final = [a, b]
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
bp = ax.boxplot(final)
plt.title("Top 10 Areas of Poverty: Total& Child Poverty")
plt.show()

# %%
#Create a histogram of the Highest Percentage of Poverty
x = bottom_ten.iloc[:,1].values
plt.hist(x, bins = 7)
plt.xlabel("Percentage of Poverty")
plt.title("Highest Percentage of Poverty Rate Histogram") 
plt.show()

# %%
#Histogram of Highest Child Poverty
x = bottom_ten.iloc[:,2].values
plt.hist(x, bins = 7)
plt.xlabel("Percentage of Child Poverty")
plt.title("Highest Percentage of Child Poverty Rate Histogram") 
plt.show()

# %%
#Histogram of both combined
plt.style.use('seaborn-deep')
x = bottom_ten.iloc[:,1].values
y = bottom_ten.iloc[:,2].values
bins = np.linspace(0, 50, 10)

plt.hist([x, y], bins, label=['Total Poverty', 'Child Poverty'])
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
