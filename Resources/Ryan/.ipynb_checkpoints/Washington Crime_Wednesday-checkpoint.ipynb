# %% [markdown]
# # Import Dependencies

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem,chisquare
from scipy.stats import linregress
import statsmodels.api as sm
import seaborn as sn

# %% [markdown]
# # Import Crime Data

# %%
filepath = "../AnyConv.com__Crime_Incidents_in_2017.csv"
df = pd.read_csv(filepath, low_memory=False)

df.head()
# Out:
#    CCN,C,80           REPORT_DAT,C,80 SHIFT,C,80 METHOD,C,80  OFFENSE,C,80  \
# 0   2111617  2017-02-06T20:11:14.000Z    EVENING      OTHERS   THEFT/OTHER
# 1   7093973  2017-06-03T12:54:27.000Z        DAY      OTHERS  THEFT F/AUTO
# 2  17400847  2017-05-25T13:07:34.000Z        DAY      OTHERS  THEFT F/AUTO
# 3  17400849  2017-05-25T19:38:01.000Z    EVENING      OTHERS   THEFT/OTHER
# 4  17400850  2017-05-25T20:18:37.000Z    EVENING      OTHERS   THEFT/OTHER
#
#                                   BLOCK,C,80  XBLOCK,N,10,0  YBLOCK,N,10,0  \
# 0      600 - 669 BLOCK OF MARYLAND AVENUE NE         400212         136281
# 1           2900 - 2999 BLOCK OF N STREET NW         394912         137666
# 2  4500 - 4599 BLOCK OF BRANDYWINE STREET NW         392231         142425
# 3        2500 - 2599 BLOCK OF 39TH STREET NW         393318         139472
# 4        4100  - 4199 BLOCK OF 8TH STREET NW         397977         141500
#
#    WARD,C,80 ANC,C,80  ...  BLOCK_GROU,C,80  CENSUS_TRA,C,80 VOTING_PRE,C,80  \
# 0          6       6C  ...         008302 1           8302.0     Precinct 84
# 1          2       2E  ...         000100 4            100.0      Precinct 5
# 2          3       3E  ...         001001 3           1001.0     Precinct 31
# 3          3       3B  ...         000702 1            702.0     Precinct 11
# 4          4       4C  ...         002400 3           2400.0     Precinct 45
#
#   LATITUDE,N,24,15  LONGITUDE,N,24,15      BID,C,80           START_DATE,C,80  \
# 0        38.894376         -76.997556  CAPITOL HILL  2017-02-01T11:55:55.000Z
# 1        38.906838         -77.058661           NaN  2017-06-03T11:54:03.000Z
# 2        38.949689         -77.089625           NaN  2017-05-12T23:00:00.000Z
# 3        38.923096         -77.077056           NaN  2017-05-14T19:10:00.000Z
# 4        38.941388         -77.023335           NaN  2017-05-09T08:00:00.000Z
#
#               END_DATE,C,80 OBJECTID,N,10,0 OCTO_RECOR,C,80
# 0                       NaN       306952475     02111617-01
# 1  2017-06-03T11:55:05.000Z       306952489     07093973-01
# 2  2017-05-13T09:00:00.000Z       306951085     17400847-01
# 3  2017-05-25T19:10:00.000Z       306951086     17400849-01
# 4  2017-05-09T18:00:00.000Z       306951087     17400850-01
#
# [5 rows x 23 columns]

# %% [markdown]
# # Overview of Data

# %%
df.columns
# Out:
# Index(['CCN,C,80', 'REPORT_DAT,C,80', 'SHIFT,C,80', 'METHOD,C,80',
#        'OFFENSE,C,80', 'BLOCK,C,80', 'XBLOCK,N,10,0', 'YBLOCK,N,10,0',
#        'WARD,C,80', 'ANC,C,80', 'DISTRICT,C,80', 'PSA,C,80', 'NEIGHBORHO,C,80',
#        'BLOCK_GROU,C,80', 'CENSUS_TRA,C,80', 'VOTING_PRE,C,80',
#        'LATITUDE,N,24,15', 'LONGITUDE,N,24,15', 'BID,C,80', 'START_DATE,C,80',
#        'END_DATE,C,80', 'OBJECTID,N,10,0', 'OCTO_RECOR,C,80'],
#       dtype='object')

# %% [markdown]
# ### Rename Columns

# %%
renamed_df = df.rename(columns={'CCN,C,80':'CCN', 'REPORT_DAT,C,80':'Report', 'SHIFT,C,80':'Shift', 
                                'METHOD,C,80':'Method', 'OFFENSE,C,80':'Offense', 'BLOCK,C,80':'Block',
                                'XBLOCK,N,10,0':'XBlock', 'YBLOCK,N,10,0':'YBlock','WARD,C,80':'Ward',
                                'ANC,C,80':'ANC', 'DISTRICT,C,80':'District', 'PSA,C,80':'PSA', 
                                'NEIGHBORHO,C,80':'Neighborhood','BLOCK_GROU,C,80':'Block_Grou', 
                                'CENSUS_TRA,C,80':'Census_Trac', 'VOTING_PRE,C,80':'Voting_Precinct',
                                'LATITUDE,N,24,15':'Latitude', 'LONGITUDE,N,24,15':'Longitude', 
                                'BID,C,80':'Bid', 'START_DATE,C,80':'Start_Date','END_DATE,C,80':'End_Date',
                                'OBJECTID,N,10,0':'Object_ID', 'OCTO_RECOR,C,80':'Octo_Recor' })
renamed_df.columns
# Out:
# Index(['CCN', 'Report', 'Shift', 'Method', 'Offense', 'Block', 'XBlock',
#        'YBlock', 'Ward', 'ANC', 'District', 'PSA', 'Neighborhood',
#        'Block_Grou', 'Census_Trac', 'Voting_Precinct', 'Latitude', 'Longitude',
#        'Bid', 'Start_Date', 'End_Date', 'Object_ID', 'Octo_Recor'],
#       dtype='object')

# %%
renamed_df.to_csv("renamed_crime_data.csv", index=False)

# %%
renamed_df.Census_Trac.unique()
# Out:
# array([ 8302.,   100.,  1001.,   702.,  2400.,  4002.,  2502.,  7605.,
#         5800., 10700.,  9301.,   600.,  8200.,  3900.,  4202.,  8702.,
#         8002.,  7200.,  2802.,  7809.,  3302., 10600.,  5900.,  4201.,
#          400., 10300.,   801.,  4901.,  1401.,   201.,  7903.,  4702.,
#         8402.,  2900.,  3000.,  8804.,  6700.,  5301., 10800.,  4902.,
#         9102.,  3500.,  8904.,  1100.,  3200.,  5201.,  3700.,  4701.,
#         8100.,  5500., 10200.,   501.,  6802.,  2301., 11100.,  6500.,
#         2002.,  5001.,  1803.,  7601.,  8903.,  6400.,  3600.,  2702.,
#         9810.,  8803.,  4400., 10400.,  9201.,   902.,  3400.,  5002.,
#         3301.,  8410.,  7901.,  9901.,  7703.,  1301.,  9903.,  9807.,
#        10100.,  6900.,  1302.,  3100.,   202.,  9700.,  9000.,  4100.,
#         2201.,  9302.,  5600.,  7100.,  6202.,  9204.,   502.,  2701.,
#         6801.,  9504.,  4600.,  1500.,  7408.,  4801.,   701.,  6600.,
#         9503.,  9203.,  4001.,  2501.,  2801.,  1901.,  9801.,  7000.,
#         7401.,  4300.,  8301.,  4802.,   901.,  1600.,  1702.,  8701.,
#         7407.,  3800.,  7603.,   802.,   300.,  2101.,  9509.,  7304.,
#         9501.,  1200.,  9508.,  7404.,  7803.,  8802., 11000.,  9904.,
#         7502.,  2202.,  8001.,  2102.,  2600.,  2302.,  7807.,  9906.,
#         7503., 10500.,  1002.,  6804.,  7806.,  9505.,  9400.,  7707.,
#         7409.,  1804.,  9602.,  7604.,  7808.,  1402.,  7504.,  7804.,
#         9907.,  9811.,  9603.,    nan,  2001.,  7406.,  1902.,  7403.,
#        10900.,  7709.,  9601.,  9803.,  9604.,  9804.,  9802.,  9902.,
#         9507.,  7708.,  9905.,  7301.])

# %% [markdown]
# - 33082 rows total
# - following rows are missing data
# - DISTRICT,C,80
# - PSA,C,80
# - NEIGHBORHO,C,80
# - BLOCK_GROU,C,80
# - CENSUS_TRA,C,80
# - BID,C,80
# - END_DATE,C,80

# %%
renamed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33082 entries, 0 to 33081
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CCN              33082 non-null  int64
#  1   Report           33082 non-null  object
#  2   Shift            33082 non-null  object
#  3   Method           33082 non-null  object
#  4   Offense          33082 non-null  object
#  5   Block            33082 non-null  object
#  6   XBlock           33082 non-null  int64
#  7   YBlock           33082 non-null  int64
#  8   Ward             33082 non-null  int64
#  9   ANC              33082 non-null  object
#  10  District         33079 non-null  float64
#  11  PSA              33079 non-null  float64
#  12  Neighborhood     32712 non-null  object
#  13  Block_Grou       32998 non-null  object
#  14  Census_Trac      32998 non-null  float64
#  15  Voting_Precinct  33082 non-null  object
#  16  Latitude         33082 non-null  float64
#  17  Longitude        33082 non-null  float64
#  18  Bid              5830 non-null   object
#  19  Start_Date       33082 non-null  object
#  20  End_Date         31585 non-null  object
#  21  Object_ID        33082 non-null  int64
#  22  Octo_Recor       33082 non-null  object
# dtypes: float64(5), int64(5), object(13)
# memory usage: 5.8+ MB

# %%
renamed_df.describe()
# Out:
#                 CCN         XBlock         YBlock          Ward      District  \
# count  3.308200e+04   33082.000000   33082.000000  33082.000000  33079.000000
# mean   1.712021e+07  399396.652711  137623.379451      4.456139      3.721394
# std    1.502723e+05    3150.374167    3358.194998      2.335491      1.909450
# min    2.111617e+06  390262.000000  127300.000000      1.000000      1.000000
# 25%    1.705836e+07  397302.250000  136093.000000      2.000000      2.000000
# 50%    1.711666e+07  399074.000000  137579.000000      5.000000      3.000000
# 75%    1.717467e+07  401342.250000  139586.000000      6.000000      5.000000
# max    2.709178e+07  407806.000000  147292.000000      8.000000      7.000000
#
#                 PSA   Census_Trac      Latitude     Longitude     Object_ID
# count  33079.000000  32998.000000  33082.000000  33082.000000  3.308200e+04
# mean     376.871489   6280.434329     38.906463    -77.006963  3.072805e+08
# std      190.730891   3124.047266      0.030251      0.036323  6.578455e+04
# min      101.000000    100.000000     38.813471    -77.112316  3.069501e+08
# 25%      207.000000   3600.000000     38.892672    -77.031103  3.072732e+08
# 50%      308.000000   7100.000000     38.906061    -77.010676  3.072815e+08
# 75%      507.000000   9000.000000     38.924144    -76.984522  3.073028e+08
# max      708.000000  11100.000000     38.993560    -76.910021  3.073348e+08

# %% [markdown]
# # Types of Offenses

# %%
renamed_df.Offense.unique()
# Out:
# array(['THEFT/OTHER', 'THEFT F/AUTO', 'ROBBERY',
#        'ASSAULT W/DANGEROUS WEAPON', 'MOTOR VEHICLE THEFT', 'BURGLARY',
#        'SEX ABUSE', 'HOMICIDE', 'ARSON'], dtype=object)

# %%
offense_type = renamed_df.groupby(['Offense']).count()['CCN']
offense_type = pd.DataFrame(offense_type)
offense_type.sort_values('CCN', ascending=False, inplace=True)
offense_type
# Out:
#                               CCN
# Offense
# THEFT/OTHER                 14445
# THEFT F/AUTO                10259
# MOTOR VEHICLE THEFT          2408
# ROBBERY                      2170
# ASSAULT W/DANGEROUS WEAPON   1856
# BURGLARY                     1531
# SEX ABUSE                     293
# HOMICIDE                      115
# ARSON                           5

# %% [markdown]
# # Histograms of Various Columns

# %% [markdown]
# ### Create Function to Plot Histogram

# %%
def plotHistogram(col, df):
    #Groupby operation on Target Column
    #Assign to temporarily DataFrame
    sub_df = df.groupby([col]).count()['CCN']
    sub_df = pd.DataFrame(sub_df)
    sub_df.sort_values('CCN', ascending=False, inplace=True)

    #Plot Histogram
    chart = sub_df.plot(kind="hist", color="yellowgreen", grid="True", figsize=(8,8), title=f"Histogram of {col}")
    chart.set_ylabel("Frequency of Offenses")
    plt.show()

# %% [markdown]
# ### Create Histograms for Each Column

# %%
cols = ['Report', 'Shift', 'Method', 'Offense', 'Block', 'XBlock',
       'YBlock', 'Ward', 'ANC', 'District', 'PSA', 'Neighborhood',
       'Block_Grou', 'Census_Trac', 'Voting_Precinct', 'Latitude', 'Longitude',
       'Bid', 'Start_Date', 'End_Date', 'Object_ID', 'Octo_Recor']
type(cols)
# Out:
# list

# %%
for col in cols:
    plotHistogram(col,renamed_df)

# %% [markdown]
# # Bar Charts of Various Columns

# %% [markdown]
# ### Create Function to Plot Bar Chart

# %%
def plotBarChart(col, df):
    #Groupby operation on Target Column
    #Assign to temporarily DataFrame
    sub_df = df.groupby([col]).count()['CCN']
    sub_df = pd.DataFrame(sub_df)
    sub_df.sort_values('CCN', ascending=False, inplace=True)
    sub_df = sub_df.head(10)

    #Plot Histogram
    chart = sub_df.plot(kind="bar", color="indigo", grid="True", figsize=(8,8), title=f"Bar Chart of {col}")
    chart.set_ylabel("Number of Offenses")
    plt.show()

# %% [markdown]
# ### Validate Function: Crime by Offense

# %%
plotBarChart('Offense', renamed_df)

# %% [markdown]
# ### Validate Function: Crime by Neighborhood

# %%
plotBarChart('Neighborhood', renamed_df)

# %% [markdown]
# ### Validate Function: Crime by Census Trac

# %%
plotBarChart('Census_Trac', renamed_df)

# %%
rr_df = renamed_df.groupby(renamed_df.Census_Trac).count()['CCN']
rr_df

sub_df = pd.DataFrame(rr_df)
sub_df.sort_values('CCN', ascending=False, inplace=True)
sub_df = sub_df.head(10)
sub_df
# Out:
#               CCN
# Census_Trac
# 5800.0       1053
# 4400.0        870
# 10700.0       659
# 10600.0       629
# 11100.0       626
# 202.0         603
# 9102.0        577
# 9603.0        510
# 3000.0        459
# 5201.0        446

# %%
(sub_df['CCN'].sum())/10
# Out:
# 643.2

# %%
sub_df["Expected"]=643.2

# %%
chisquare(sub_df['CCN'],sub_df['Expected'])
# Out:
# Power_divergenceResult(statistic=492.35012437810934, pvalue=2.4970783146911526e-100)

# %%
new_list =[1000, 850, 650, 630, 630, 600, 550, 500, 450, 450]
sub_df['Expected']= new_list
sub_df
# Out:
#               CCN  Expected
# Census_Trac
# 5800.0       1053      1000
# 4400.0        870       850
# 10700.0       659       650
# 10600.0       629       630
# 11100.0       626       630
# 202.0         603       600
# 9102.0        577       550
# 9603.0        510       500
# 3000.0        459       450
# 5201.0        446       450

# %%
chisquare(sub_df['CCN'],sub_df['Expected'])
# Out:
# Power_divergenceResult(statistic=5.187197847903731, pvalue=0.8176938877718074)

# %% [markdown]
# ### Create Bar Charts for Each Column

# %%
fields = ['Report', 'Method', 'Offense', 'Ward', 'District', 'Neighborhood',
        'Census_Trac', 'Voting_Precinct']

# %% [markdown]
# - not sure why function does not work in this loop

# %%
for field in fields:
    plotBarChart(field,renamed_df)

# %% [markdown]
# # Types of Weapon

# %%
weapon = df.groupby(['METHOD,C,80'])["CCN,C,80"].count()
#weapon

weapon.plot(kind="pie", title="Distribution of Crime by Weapon")
plt.show()

# %% [markdown]
# # Correlation

# %%
renamed_df.columns
# Out:
# Index(['CCN', 'Report', 'Shift', 'Method', 'Offense', 'Block', 'XBlock',
#        'YBlock', 'Ward', 'ANC', 'District', 'PSA', 'Neighborhood',
#        'Block_Grou', 'Census_Trac', 'Voting_Precinct', 'Latitude', 'Longitude',
#        'Bid', 'Start_Date', 'End_Date', 'Object_ID', 'Octo_Recor'],
#       dtype='object')

# %%
renamed_df.corr()
# Out:
#                   CCN    XBlock    YBlock      Ward  District       PSA  \
# CCN          1.000000 -0.023778  0.013871 -0.027237 -0.023326 -0.023277
# XBlock      -0.023778  1.000000 -0.431536  0.731881  0.627243  0.627632
# YBlock       0.013871 -0.431536  1.000000 -0.604422 -0.339318 -0.342631
# Ward        -0.027237  0.731881 -0.604422  1.000000  0.576764  0.576670
# District    -0.023326  0.627243 -0.339318  0.576764  1.000000  0.999924
# PSA         -0.023277  0.627632 -0.342631  0.576670  0.999924  1.000000
# Census_Trac -0.015033  0.662248 -0.521944  0.582619  0.398355  0.399889
# Latitude     0.013869 -0.431537  1.000000 -0.604424 -0.339336 -0.342648
# Longitude   -0.023775  1.000000 -0.431603  0.731845  0.627175  0.627565
# Object_ID   -0.137417  0.077595 -0.037003  0.062215  0.075858  0.075729
#
#              Census_Trac  Latitude  Longitude  Object_ID
# CCN            -0.015033  0.013869  -0.023775  -0.137417
# XBlock          0.662248 -0.431537   1.000000   0.077595
# YBlock         -0.521944  1.000000  -0.431603  -0.037003
# Ward            0.582619 -0.604424   0.731845   0.062215
# District        0.398355 -0.339336   0.627175   0.075858
# PSA             0.399889 -0.342648   0.627565   0.075729
# Census_Trac     1.000000 -0.521892   0.662361   0.051251
# Latitude       -0.521892  1.000000  -0.431604  -0.037001
# Longitude       0.662361 -0.431604   1.000000   0.077593
# Object_ID       0.051251 -0.037001   0.077593   1.000000

# %% [markdown]
# ### Heatmap to Illustrate Correlation

# %%
sn.heatmap(renamed_df.corr())
plt.show()

# %% [markdown]
# # Scatter Plots

# %% [markdown]
# ### Function to Create Scatter Plot

# %%
plt.figure(figsize=(8, 8))
plt.scatter(renamed_df.Census_Trac, renamed_df.XBlock, c="blueviolet", edgecolors="black",
           alpha=0.35)
plt.title("MPG vs displacement")
plt.xlabel("MPG")
plt.ylabel("displacement")
plt.show()

# %%
def makeScatter(col1, col2, df):  
    plt.figure(figsize=(8, 8))
    plt.scatter(df[col1], df[col2], c="blueviolet", edgecolors="black", alpha=0.35)
    plt.title(f"{col1.title()} vs {col2.title()}")
    plt.xlabel(f"{col1.title()}")
    plt.ylabel(f"{col2.title()}")
    plt.tight_layout
    plt.show()

# %%
makeScatter("Census_Trac","XBlock", renamed_df)

# %% [markdown]
# ### Create Scatter Plots for Census Trac

# %%
test = renamed_df.corr()
test.index
# Out:
# Index(['CCN', 'XBlock', 'YBlock', 'Ward', 'District', 'PSA', 'Census_Trac',
#        'Latitude', 'Longitude', 'Object_ID'],
#       dtype='object')

# %%
cols = ['CCN', 'XBlock', 'YBlock', 'Ward', 'District', 'PSA', 'Census_Trac',
       'Latitude', 'Longitude', 'Object_ID']

# %%
for col in cols:
    makeScatter("Census_Trac", col, renamed_df)

# %% [markdown]
# # Create Google Map of Crime

# %% [markdown]
# ### Import Dependencies

# %%
import gmaps
import json
from api_keys import g_key

# %%
gmaps.configure(api_key=g_key)

# %%
renamed_df.columns
# Out:
# Index(['CCN', 'Report', 'Shift', 'Method', 'Offense', 'Block', 'XBlock',
#        'YBlock', 'Ward', 'ANC', 'District', 'PSA', 'Neighborhood',
#        'Block_Grou', 'Census_Trac', 'Voting_Precinct', 'Latitude', 'Longitude',
#        'Bid', 'Start_Date', 'End_Date', 'Object_ID', 'Octo_Recor'],
#       dtype='object')

# %% [markdown]
# ### Create Heatmap based on Crime by Census Tract

# %%
ww_df = renamed_df.groupby(renamed_df.Census_Trac).count()['CCN']
ww_df

sub_df = pd.DataFrame(ww_df)
sub_df.sort_values('CCN', ascending=False, inplace=True)
sub_df = sub_df.head(10)
sub_df
# Out:
#               CCN
# Census_Trac
# 5800.0       1053
# 4400.0        870
# 10700.0       659
# 10600.0       629
# 11100.0       626
# 202.0         603
# 9102.0        577
# 9603.0        510
# 3000.0        459
# 5201.0        446

# %%
mask = renamed_df['Census_Trac'] == 5800.0
temp_df = renamed_df[['Latitude', 'Longitude']].loc[mask]
temp_df.reset_index(drop=True)
# Out:
#        Latitude  Longitude
# 0     38.897203 -77.022433
# 1     38.902941 -77.022988
# 2     38.899805 -77.024982
# 3     38.897338 -77.020923
# 4     38.901364 -77.026273
# ...         ...        ...
# 1048  38.897337 -77.024969
# 1049  38.899814 -77.028867
# 1050  38.897823 -77.028093
# 1051  38.898309 -77.028854
# 1052  38.898309 -77.028854
#
# [1053 rows x 2 columns]

# %%
temp_df[['Latitude', 'Longitude']].mean()
# Out:
# Latitude     38.898653
# Longitude   -77.024615
# dtype: float64

# %% [markdown]
# ### Create List of Census Areas

# %%
census_trac_list = sub_df.index.tolist()
census_trac_list
# Out:
# [5800.0,
#  4400.0,
#  10700.0,
#  10600.0,
#  11100.0,
#  202.0,
#  9102.0,
#  9603.0,
#  3000.0,
#  5201.0]

# %%
def CreateCensusAreaLocation(area, df):
    
    #Filter for the Census Area
    mask = df['Census_Trac'] == area
    #Capture all the lat/long for the area
    temp_df = df[['Latitude', 'Longitude']].loc[mask]
    #Average the lat/long
    location = temp_df[['Latitude', 'Longitude']].mean()
    
    return location

# %%
liz_list = CreateCensusAreaLocation(5800,renamed_df)
liz_list
# Out:
# Latitude     38.898653
# Longitude   -77.024615
# dtype: float64

# %%
hin_list = []

for thing in census_trac_list:
    hin_list.append(CreateCensusAreaLocation(thing,renamed_df))

# %%
hin_list
# Out:
# [Latitude     38.898653
#  Longitude   -77.024615
#  dtype: float64,
#  Latitude     38.916758
#  Longitude   -77.026966
#  dtype: float64,
#  Latitude     38.904683
#  Longitude   -77.041501
#  dtype: float64,
#  Latitude     38.904585
#  Longitude   -77.002610
#  dtype: float64,
#  Latitude     38.922741
#  Longitude   -76.969642
#  dtype: float64,
#  Latitude     38.906516
#  Longitude   -77.065324
#  dtype: float64,
#  Latitude     38.921536
#  Longitude   -76.989902
#  dtype: float64,
#  Latitude     38.892909
#  Longitude   -76.947973
#  dtype: float64,
#  Latitude     38.929442
#  Longitude   -77.031548
#  dtype: float64,
#  Latitude     38.910182
#  Longitude   -77.033132
#  dtype: float64]

# %%
num_of_crimes = sub_df['CCN'].to_list()
num_of_crimes
# Out:
# [1053, 870, 659, 629, 626, 603, 577, 510, 459, 446]

# %%
locations = hin_list

figure_layout = {
    'width': '950px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

fig = gmaps.figure(map_type="HYBRID", layout=figure_layout)
heat_layer = gmaps.heatmap_layer(locations, weights=num_of_crimes)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', margin='0 auto 0 auto', padding='1px', wi…

# %%
yyf = renamed_df.groupby(['Census_Trac', 'Latitude', 'Longitude']).count()['CCN']
yyf = pd.DataFrame(yyf)
yyf.reset_index(inplace=True)
yyf
#sub_df = pd.DataFrame(ww_df)
#sub_df.sort_values('CCN', ascending=False, inplace=True)
#sub_df = sub_df.head(10)
#sub_df
# Out:
#       Census_Trac   Latitude  Longitude  CCN
# 0           100.0  38.902550 -77.058577    4
# 1           100.0  38.902584 -77.061955   27
# 2           100.0  38.902585 -77.059614   19
# 3           100.0  38.902594 -77.060629   20
# 4           100.0  38.903008 -77.061137    2
# ...           ...        ...        ...  ...
# 6984      11100.0  38.932720 -76.968571    1
# 6985      11100.0  38.932863 -76.964569    3
# 6986      11100.0  38.933232 -76.962055    2
# 6987      11100.0  38.934089 -76.964845    2
# 6988      11100.0  38.934530 -76.964787   35
#
# [6989 rows x 4 columns]

# %%
mask = yyf['Census_Trac'] == 100
yyf.loc[mask]
# Out:
#     Census_Trac   Latitude  Longitude  CCN
# 0         100.0  38.902550 -77.058577    4
# 1         100.0  38.902584 -77.061955   27
# 2         100.0  38.902585 -77.059614   19
# 3         100.0  38.902594 -77.060629   20
# 4         100.0  38.903008 -77.061137    2
# ..          ...        ...        ...  ...
# 75        100.0  38.912537 -77.065549    1
# 76        100.0  38.912559 -77.057743    1
# 77        100.0  38.912645 -77.064592    3
# 78        100.0  38.912666 -77.060130    3
# 79        100.0  38.913168 -77.064166    1
#
# [80 rows x 4 columns]

# %%
locations = yyf[['Latitude','Longitude']]

num_of_crimes = yyf.CCN

figure_layout = {
    'width': '950px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

fig = gmaps.figure(map_type="HYBRID", layout=figure_layout)
heat_layer = gmaps.heatmap_layer(locations, weights=num_of_crimes)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', margin='0 auto 0 auto', padding='1px', wi…
